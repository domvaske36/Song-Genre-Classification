# %% [markdown]
# <a href="https://colab.research.google.com/github/domvaske36/Song-Genre-Classification/blob/main/MATH2015_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Collection References

# %% [markdown]
# Spotify API Documentation: <br>
# **Acousticness**- A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic. <br>
# **Danceability** - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable. <br>
# **Energy**- Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy. <br>
# **Instrumentalness** - Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0. <br>
# **Key** - The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1. <br>
# **Liveness**- Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live. <br>
# **Loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db. <br>
# **Mode** - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0. <br>
# **Speechiness** - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks. <br>
# **Tempo** - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration. <br>
# **Time Signature** - An estimated time signature. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure). The time signature ranges from 3 to 7 indicating time signatures of "3/4", to "7/4". <br>
# **Valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %% [markdown]
# #Data Collection

# %%
import pandas as pd

heavy_metal = 'https://drive.google.com/uc?id=1A4Csje5zXowMnyUD-eYilsfAxUWWRMa7'
latino_pop = 'https://drive.google.com/uc?id=1PKRKckwwvR_Xx6EHb9qGBvCB_zrB25Q1'
neo_soul = 'https://drive.google.com/uc?id=13An-NKcHvNWIPr6m4J1XIqY1s4FJX2Ew'
punk_pop = 'https://drive.google.com/uc?id=1gTWf0vaDVCNyp_2D8hkgEj_wSXgHBm_B'
study_music = 'https://drive.google.com/uc?id=1vQYX7ad7LLlieK_4CH3PIf10hwZ2f982'
entire_dataset = 'https://drive.google.com/uc?id=18o1fkUBo7DmzkkqKEq2tOkVDmvayWFJZ'

df_heavy_metal = pd.read_csv(heavy_metal)
df_latino_pop = pd.read_csv(latino_pop)
df_neo_soul = pd.read_csv(neo_soul)
df_punk_pop = pd.read_csv(punk_pop)
df_study_music = pd.read_csv(study_music)
#entire dataset
df = pd.read_csv(entire_dataset)

# %%
df.head(10)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.264   0.986   11    -5.059     1       0.1020      0.000004
# 1         0.457   0.997    1    -4.992     0       0.0634      0.000008
# 2         0.500   0.991    1    -6.416     1       0.0645      0.000034
# 3         0.242   0.998   11    -5.640     1       0.0894      0.000008
# 4         0.233   0.999    5    -4.225     1       0.0830      0.000003
# 5         0.512   0.996    2    -2.100     1       0.1140      0.000056
# 6         0.286   0.982    0    -3.828     0       0.1310      0.000034
# 7         0.480   0.995    6    -2.547     1       0.0961      0.000021
# 8         0.318   0.984    2    -4.588     1       0.1020      0.000149
# 9         0.466   0.833    7    -4.215     1       0.3040      0.026600
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.006250    0.0535   0.2270  106.161  6GYyGwbJeHyFj9po98ZGpS
# ...

# %%
df.tail(10)
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 490         0.214  0.1760    2   -16.865     0       0.0303         0.947
# 491         0.562  0.0556   10   -20.609     1       0.0828         0.972
# 492         0.755  0.1360    2   -14.287     0       0.0908         0.952
# 493         0.374  0.3100    8   -19.572     1       0.1820         0.856
# 494         0.690  0.0687   11   -21.329     0       0.0743         0.929
# 495         0.804  0.3140    9   -11.068     0       0.0951         0.302
# 496         0.755  0.1130    7   -23.899     0       0.0527         0.832
# 497         0.548  0.1690   10   -14.918     0       0.0484         0.936
# 498         0.762  0.1910    1   -18.740     0       0.0804         0.903
# 499         0.656  0.0388    4   -26.740     1       0.0411         0.817
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 490             0.927    0.1340   0.1220   78.975  2AOT6tZXAwaATDPyF3NWJu
# ...

# %% [markdown]
# #Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Danceability vs Tempo
dance= df['danceability']
tempo= df['tempo']
plt.figure(figsize=(10, 6))
plt.scatter(dance, tempo, color='b', alpha=0.6)
plt.title('Danceability vs Tempo')
plt.xlabel('Danceability')
plt.ylabel('Tempo')
plt.grid(True)
plt.show()

# %% [markdown]
# ##RadarPlot

# %%
#drop non-numeric columns
df_heavy_metal= df_heavy_metal.drop(['id'], axis=1)
df_latino_pop= df_latino_pop.drop(['id'], axis=1)
df_neo_soul= df_neo_soul.drop(['id'], axis=1)
df_punk_pop= df_punk_pop.drop(['id'], axis=1)
df_study_music= df_study_music.drop(['id'], axis=1)

# %%
#scaling the data using min-max scaler
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
scaler = MinMaxScaler(feature_range=(0, 1))
df_heavy_metal_scaled = pd.DataFrame(scaler.fit_transform(df_heavy_metal), columns=df_heavy_metal.columns)
df_latino_pop_scaled = pd.DataFrame(scaler.fit_transform(df_latino_pop), columns=df_latino_pop.columns)
df_neo_soul_scaled = pd.DataFrame(scaler.fit_transform(df_neo_soul), columns=df_neo_soul.columns)
df_punk_pop_scaled = pd.DataFrame(scaler.fit_transform(df_punk_pop), columns=df_punk_pop.columns)
df_study_music_scaled = pd.DataFrame(scaler.fit_transform(df_study_music), columns=df_study_music.columns)

# %%
#9 Features
features_of_heavy_metal_data = df_heavy_metal_scaled[['acousticness', 'danceability', 'duration_ms', 'energy','valence', 'tempo', 'speechiness', 'mode', 'loudness', 'liveness', 'key', 'instrumentalness']]
features_of_latino_pop_data = df_latino_pop_scaled[['acousticness', 'danceability', 'duration_ms', 'energy','valence', 'tempo', 'speechiness', 'mode', 'loudness', 'liveness', 'key', 'instrumentalness']]
features_of_neo_soul_data = df_neo_soul_scaled[['acousticness', 'danceability', 'duration_ms', 'energy','valence', 'tempo', 'speechiness', 'mode', 'loudness', 'liveness', 'key', 'instrumentalness']]
features_of_punk_pop_data = df_punk_pop_scaled[['acousticness', 'danceability', 'duration_ms', 'energy','valence', 'tempo', 'speechiness', 'mode', 'loudness', 'liveness', 'key', 'instrumentalness']]
features_of_study_music_data = df_study_music_scaled[['acousticness', 'danceability', 'duration_ms', 'energy','valence', 'tempo', 'speechiness', 'mode', 'loudness', 'liveness', 'key', 'instrumentalness']]

# %%
# Assuming features_of_neoSoul_data and features_of_funk_data are DataFrames containing the features

# Extract feature labels from the columns of both datasets
labels = list(features_of_heavy_metal_data.columns.values)

# Concatenate mean values for the features from both playlists
stats = np.asarray(features_of_heavy_metal_data.mean())  # Convert to 1-dimensional array for Playlist1
stats2 = np.asarray(features_of_latino_pop_data.mean())  # Convert to 1-dimensional array for Playlist2
stats3 = np.asarray(features_of_neo_soul_data.mean())
stats4 = np.asarray(features_of_punk_pop_data.mean())
stats5 = np.asarray(features_of_study_music_data.mean())

# Calculate angles for the radar plot
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)

# Increase the figure size to move the labels further out
fig = plt.figure(figsize=(40, 20))

# Heavy metal points
ax = fig.add_subplot(221, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2, label="heavy metal", color='royalblue')  # Set color for Playlist1 (light blue)
ax.fill(angles, stats, alpha=0.25, facecolor='royalblue')  # Set color for Playlist1

# Latino Pop
ax.plot(angles, stats2, 'o-', linewidth=2, label="latino+pop", color='orange')  # Set color for Playlist2 (orange)
ax.fill(angles, stats2, alpha=0.25, facecolor='orange')  # Set color for Playlist2

# Neo Soul
ax.plot(angles, stats3, 'o-', linewidth=2, label="neo soul", color='cyan')
ax.fill(angles, stats3, alpha=0.25, facecolor='cyan')

# Punk Pop
ax.plot(angles, stats4, 'o-', linewidth=2, label="punk pop", color='brown')
ax.fill(angles, stats4, alpha=0.25, facecolor='brown')

# Study Music
ax.plot(angles, stats5, 'o-', linewidth=2, label="study music", color='green')
ax.fill(angles, stats5, alpha=0.25, facecolor='green')

ax.set_rlabel_position(0)  # Manually adjust the radial position of y-axis labels
ax.set_yticklabels([0.2, 0.8, 0.6, 0.8], color="grey", size=12)
plt.ylim(0, 1)

# Set the maximum radial value for zooming in
ax.set_rmax(0.95)

ax.set_thetagrids(angles * 180/np.pi, labels, fontsize=13)  # Set labels on the plot

ax.set_title('Mean Value comparison of the audio features in heavy metal, latino pop, neo-soul, punk pop, and study music')

plt.legend(loc='best', bbox_to_anchor=(0.1, 0.1))

# Save the plot as an image file
plt.savefig('radar_chart.png')

plt.show()
# Out:
# <ipython-input-9-4afc95a66483>:41: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([0.2, 0.8, 0.6, 0.8], color="grey", size=12)

# %%
from google.colab import files

files.download('radar_chart.png')

# %% [markdown]
# #PCA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.264   0.986   11    -5.059     1       0.1020      0.000004
# 1         0.457   0.997    1    -4.992     0       0.0634      0.000008
# 2         0.500   0.991    1    -6.416     1       0.0645      0.000034
# 3         0.242   0.998   11    -5.640     1       0.0894      0.000008
# 4         0.233   0.999    5    -4.225     1       0.0830      0.000003
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0           0.00625    0.0535    0.227  106.161  6GYyGwbJeHyFj9po98ZGpS
# 1           0.89900    0.1380    0.530  110.021  2gSUtqdBM4k39be9FzQjOH
# 2           0.91600    0.3420    0.360  109.935  7nrJ5usA4Ydp2feVrVW8lB
# 3           0.88000    0.2840    0.180  114.642  4E6wpXABj8XosZEPXZz2OK
# 4           0.91100    0.5180    0.326  113.358  4PHppm7v48ys7YrVelKSYq
#
#    duration_ms  time_signature        genre
# 0       274587               4  heavy_metal
# ...

# %%
df_pca = df.drop(['id', 'mode', 'genre', 'key', 'liveness'], axis=1)
df_genre = df['genre']
df_pca.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.264   0.986    -5.059       0.1020      0.000004
# 1         0.457   0.997    -4.992       0.0634      0.000008
# 2         0.500   0.991    -6.416       0.0645      0.000034
# 3         0.242   0.998    -5.640       0.0894      0.000008
# 4         0.233   0.999    -4.225       0.0830      0.000003
#
#    instrumentalness  valence    tempo  duration_ms  time_signature
# 0           0.00625    0.227  106.161       274587               4
# 1           0.89900    0.530  110.021       248933               4
# 2           0.91600    0.360  109.935       351040               4
# 3           0.88000    0.180  114.642       442733               4
# 4           0.91100    0.326  113.358       264413               4

# %%
df_standardized = (df_pca - df_pca.mean()) / df_pca.std()
df_standardized.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -1.447870  1.154222  0.457295    -0.041528     -0.779876
# 1     -0.508028  1.189503  0.463821    -0.476455     -0.779863
# 2     -0.298634  1.170259  0.325128    -0.464061     -0.779790
# 3     -1.555002  1.192711  0.400708    -0.183499     -0.779864
# 4     -1.598829  1.195918  0.538524    -0.255611     -0.779878
#
#    instrumentalness   valence     tempo  duration_ms  time_signature
# 0         -0.579765 -0.852027 -0.430346     0.728972           0.218
# 1          1.887406  0.347860 -0.310724     0.387121           0.218
# 2          1.934387 -0.325344 -0.313389     1.747741           0.218
# 3          1.834898 -1.038148 -0.167518     2.969590           0.218
# 4          1.920569 -0.459985 -0.207309     0.593399           0.218

# %%
u,s,Pt = np.linalg.svd(df_standardized)
print('The matrix P^t is \n', Pt,'\n')
# Out:
# The matrix P^t is
#  [[ 0.24521642  0.41273548  0.46394673  0.11373076 -0.43569632 -0.42870865
#    0.34286638  0.00723841  0.19056888  0.11742417]
#  [-0.59419893  0.35378031  0.01914497 -0.15673965 -0.26393462 -0.0210649
#   -0.29192431  0.49309936  0.08669576 -0.30140526]
#  [ 0.1360131   0.0420855   0.02151643 -0.49749463  0.0144273  -0.01117753
#    0.27158465  0.40333518 -0.66293329  0.23561464]
#  [-0.23071646  0.15202748  0.04854925 -0.48885812 -0.1502      0.05693375
#   -0.29821385 -0.46810321  0.12462905  0.57700283]
#  [-0.20943911 -0.00260939 -0.05546301  0.59818259  0.05761348 -0.0288036
#   -0.11753556  0.33232994 -0.09772058  0.67622024]
#  [ 0.12267731 -0.25120963 -0.17045204 -0.31615267  0.09454065  0.03424865
#    0.24431992  0.44402261  0.69092993  0.22021402]
#  [ 0.48267988  0.11298422  0.426623    0.01684009 -0.03593837  0.55872545
#   -0.45175944  0.22614593  0.05512591  0.01519198]
#  [ 0.28195276 -0.29136464 -0.039038   -0.10488632 -0.00935312 -0.67561173
# ...

# %%
s
# Out:
# array([44.79384232, 27.09959464, 25.2460815 , 21.87065573, 20.75048642,
#        16.34251852, 13.40468586, 12.24293352,  8.60780695,  5.66599364])

# %%
s_square = s**2
s_square
percent_variance = s_square/np.sum(s_square) * 100
labels = ['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10']
plt.bar(x=range(1,11), height=percent_variance, tick_label=labels)
plt.xlabel('Principal Component')
plt.ylabel('Percentage of Variance Explained (%)')
plt.title('Scree Plot')
plt.show()

# %%
percent_variance
# Out:
# array([40.21018658, 14.71719499, 12.7728383 ,  9.58568301,  8.62891156,
#         5.35226275,  3.60091389,  3.00379601,  1.48485652,  0.64335639])

# %%
# truncating by keeping first k components
k = 6

#truncated P matrix that keeps the first k columns
P_trunc = np.transpose(Pt)[:,:k]

transformed_data_trunc = np.dot(df_standardized, P_trunc)
# # the first k rows of the transformed data
# transformed_data_trunc = P_trunc_t @ df_pca
transformed_data_trunc
# Out:
# array([[ 0.78639498,  1.53599286, -0.95949216,  1.30832235,  0.25509934,
#         -0.47355167],
#        [ 0.27440239,  0.68541598, -0.04049581,  0.99382437, -0.34129245,
#         -0.03615155],
#        [ 0.2631506 ,  0.86174896, -1.10840679,  1.30403825, -0.42606115,
#          0.79014128],
#        ...,
#        [-3.32384444, -1.27294518,  0.03069473,  0.98307178, -0.28044141,
#         -0.74286272],
#        [-2.96464321, -1.57804945,  0.78106557, -0.17996807,  0.04318411,
#         -0.1896956 ],
#        [-3.5505644 , -1.76909563,  0.29113852,  0.62005752, -0.4279778 ,
#         -0.21156873]])

# %%
###USING SCIKIT LEARN

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


# Create a DataFrame
df_slPCA = df_standardized

# Separate features (X) and target (y)
X = df_slPCA
y = df_genre

# Apply PCA
pca = PCA(n_components=6)
X_pca = pca.fit_transform(X)




# Variance explained by each component
print(f'Explained variance ratio: {pca.explained_variance_ratio_}')
print(f'Cumulative explained variance: {np.cumsum(pca.explained_variance_ratio_)}')
X_pca
# Out:
# Explained variance ratio: [0.40210187 0.14717195 0.12772838 0.09585683 0.08628912 0.05352263]
# Cumulative explained variance: [0.40210187 0.54927382 0.6770022  0.77285903 0.85914814 0.91267077]
# array([[ 0.78639498, -1.53599286,  0.95949216,  1.30832235,  0.25509934,
#         -0.47355167],
#        [ 0.27440239, -0.68541598,  0.04049581,  0.99382437, -0.34129245,
#         -0.03615155],
#        [ 0.2631506 , -0.86174896,  1.10840679,  1.30403825, -0.42606115,
#          0.79014128],
#        ...,
#        [-3.32384444,  1.27294518, -0.03069473,  0.98307178, -0.28044141,
#         -0.74286272],
#        [-2.96464321,  1.57804945, -0.78106557, -0.17996807,  0.04318411,
#         -0.1896956 ],
#        [-3.5505644 ,  1.76909563, -0.29113852,  0.62005752, -0.4279778 ,
#         -0.21156873]])

# %% [markdown]
# # K Nearest Neighbors (KNN)

# %%
#import train test libray to use some data as test values
from sklearn.model_selection import train_test_split
#import KNN Classifier to use KNN algorithm
from sklearn.neighbors import KNeighborsClassifier
#Performance evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

#test size (percentage) of data
ts = 0.2

#split the transformed PCA data (X_pca) and corresponding genres (y = df_genre)
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = ts, random_state=42)

# %%
#initialize and train the KNN Classifier

#number of closest neighbors to consider
k = 5

#train the model on training data
#assumes euclidean distance calculation without specifying
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Make a prediction
y_pred = knn.predict(X_test)

#Evaluate the model

#Accuracy score: correct predictions / total predictions
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}\n")

#Table where rows = number of songs in an actual genre, and
#columns = how many songs were predicted as a different genre
#Diagonal entries are number of correct predictions
conf_matrix = confusion_matrix(y_test, y_pred)
class_labels = sorted(y_test.unique())
conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=[f'Actual: {label}' for label in class_labels],
                              columns=[f'Predicted: {label}' for label in class_labels])

print("Confusion Matrix:\n\n", conf_matrix_df,"\n")

#detailed breakdown of performance for each class
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n")
print(class_report)
# Out:
# Accuracy: 0.89
#
# Confusion Matrix:
#
#                       Predicted: heavy_metal  Predicted: latino_pop  \
# Actual: heavy_metal                      25                      0
# Actual: latino_pop                        0                     11
# Actual: neo_soul                          0                      1
# Actual: punk_pop                          4                      0
# Actual: study_music                       0                      0
#
#                      Predicted: neo_soul  Predicted: punk_pop  \
# Actual: heavy_metal                    1                    2
# Actual: latino_pop                     3                    0
# Actual: neo_soul                       9                    0
# Actual: punk_pop                       0                   20
# Actual: study_music                    0                    0
#
#                      Predicted: study_music
# Actual: heavy_metal                       0
# Actual: latino_pop                        0
# ...

# %%
import seaborn as sns
#Table where rows = number of songs in an actual genre, and
#columns = how many songs were predicted as a different genre
#Diagonal entries are number of correct predictions
conf_matrix = confusion_matrix(y_test, y_pred)
class_labels = ['Heavy Metal', 'Latino Pop', 'Neo Soul', 'Punk Pop', 'Study Music']
conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=[f'Actual: {label}' for label in class_labels],
                              columns=[f'Predicted: {label}' for label in class_labels])

sns.heatmap(conf_matrix, annot=True, cmap='viridis', fmt="d", xticklabels=class_labels, yticklabels=class_labels)
sns.set(font_scale=1.2)
plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted Genre')
plt.ylabel('Actual Genre')
plt.show()

#detailed breakdown of performance for each class
class_report = classification_report(y_test, y_pred, target_names=class_labels)

# %% [markdown]
# ## Understanding Classification Report
#
# ### Precision
# - **Definition**: Measures how many predictions for a class were correct.
# - **Example**: 86% of samples predicted as `heavy_metal` were actually `heavy_metal`.
#
# ### Recall
# - **Definition**: Measures how many of the actual samples of a class were correctly identified.
# - **Example**: 89% of actual `heavy_metal` songs were correctly predicted as `heavy_metal`.
#
# ### F1-Score
# - **Definition**: Combines precision and recall into a single metric.
# - **Formula**:
#   $$
#   F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
#   $$
#
#
# ### Support
# - **Definition**: Number of actual instances of each class in the test set.
# - **Example**: 28 songs in the test set were `heavy_metal`.

# %% [markdown]
# # Optimize K in KNN

# %%
#Finding an optimize value for k
k_values = range(1,20)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  accuracies.append(knn.score(X_test,y_test))

# %%
#Plotting Accuracies

plt.plot(k_values, accuracies, marker='o', linestyle='--')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Neighbors (k)')
plt.grid(True)
plt.show()

# %% [markdown]
# Optimal value of k appears to be 7 neighbors with an accuracy of 92% prediction

# %% [markdown]
# #Logistic Regression

# %%
#import train test libray to use some data as test values
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
#Performance evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

#test size (percentage) of data
ts = 0.2

#split the transformed PCA data (X_pca) and corresponding genres (y = df_genre)
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = ts, random_state=42)

# %%
#Train the model
from sklearn.linear_model import LogisticRegression

# Initialize the logistic regression model - automatically uses One-vs-Rest Logistic Regression
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
#Accuracy score: correct predictions / total predictions
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}\n")

#Table where rows = number of songs in an actual genre, and
#columns = how many songs were predicted as a different genre
#Diagonal entries are number of correct predictions
conf_matrix = confusion_matrix(y_test, y_pred)
class_labels = sorted(y_test.unique())
conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=[f'Actual: {label}' for label in class_labels],
                              columns=[f'Predicted: {label}' for label in class_labels])

print("Confusion Matrix:\n\n", conf_matrix_df,"\n")

#detailed breakdown of performance for each class
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n")
print(class_report)
# Out:
# Accuracy: 0.90
#
# Confusion Matrix:
#
#                       Predicted: heavy_metal  Predicted: latino_pop  \
# Actual: heavy_metal                      25                      0
# Actual: latino_pop                        0                     12
# Actual: neo_soul                          0                      1
# Actual: punk_pop                          2                      2
# Actual: study_music                       0                      0
#
#                      Predicted: neo_soul  Predicted: punk_pop  \
# Actual: heavy_metal                    2                    1
# Actual: latino_pop                     2                    0
# Actual: neo_soul                       9                    0
# Actual: punk_pop                       0                   20
# Actual: study_music                    0                    0
#
#                      Predicted: study_music
# Actual: heavy_metal                       0
# Actual: latino_pop                        0
# ...

# %%
import seaborn as sns
#Table where rows = number of songs in an actual genre, and
#columns = how many songs were predicted as a different genre
#Diagonal entries are number of correct predictions
conf_matrix = confusion_matrix(y_test, y_pred)
class_labels = ['Heavy Metal', 'Latino Pop', 'Neo Soul', 'Punk Pop', 'Study Music']
conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=[f'Actual: {label}' for label in class_labels],
                              columns=[f'Predicted: {label}' for label in class_labels])

sns.heatmap(conf_matrix, annot=True, cmap='viridis', fmt="d", xticklabels=class_labels, yticklabels=class_labels)
sns.set(font_scale=1.2)
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted Genre')
plt.ylabel('Actual Genre')
plt.show()


#detailed breakdown of performance for each class
class_report = classification_report(y_test, y_pred, target_names=class_labels)
print("Classification Report:\n")
print(class_report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  Heavy Metal       0.93      0.89      0.91        28
#   Latino Pop       0.80      0.86      0.83        14
#     Neo Soul       0.69      0.90      0.78        10
#     Punk Pop       0.95      0.83      0.89        24
#  Study Music       1.00      1.00      1.00        24
#
#     accuracy                           0.90       100
#    macro avg       0.87      0.90      0.88       100
# weighted avg       0.91      0.90      0.90       100

# %% [markdown]
# #Prediction

# %% [markdown]
# #Validation
